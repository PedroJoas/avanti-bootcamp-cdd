# %%
import pandas as pd

# %%
dictionary = pd.DataFrame([
    {
        "variavel": "total_bill",
        "descricao": "Valor total da conta (em dólares)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "variavel": "tip",
        "descricao": "Valor da gorjeta (em dólares)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },
    {
        "variavel": "sex",
        "descricao": "Sexo da pessoa que pagou a conta",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
    {
        "variavel": "smoker",
        "descricao": "Indica se havia fumantes no grupo",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
    {
        "variavel": "day",
        "descricao": "Dia da semana em que a refeição foi consumida",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
    {
        "variavel": "time",
        "descricao": "Momento do dia em que a refeição foi consumida",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },
    {
        "variavel": "size",
        "descricao": "Número de pessoas no grupo",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    }
])

# %%
dictionary
# Out:
#      variavel                                       descricao          tipo  \
# 0  total_bill               Valor total da conta (em dólares)  quantitativa
# 1         tip                   Valor da gorjeta (em dólares)  quantitativa
# 2         sex                Sexo da pessoa que pagou a conta   qualitativa
# 3      smoker               Indica se havia fumantes no grupo   qualitativa
# 4         day   Dia da semana em que a refeição foi consumida   qualitativa
# 5        time  Momento do dia em que a refeição foi consumida   qualitativa
# 6        size                      Número de pessoas no grupo  quantitativa
#
#     subtipo
# 0  contínua
# 1  contínua
# 2   nominal
# 3   nominal
# 4   nominal
# 5   nominal
# 6  discreta

# %%
dictionary.to_csv('../data/external/data-dict.csv', index=False)
